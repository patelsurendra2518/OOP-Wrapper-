# %%
class BankAccount:
    def __init__(self, name, balance):
        self.name = name          # public
        self.__balance = balance  # private (encapsulation)

    # Getter method
    def get_balance(self):
        return self.__balance

    # Deposit method
    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount
            print("Amount deposited successfully")
        else:
            print("Invalid amount")

    # Withdraw method
    def withdraw(self, amount):
        if amount > self.__balance:
            print("Insufficient balance!")
        elif amount <= 0:
            print("Invalid amount")
        else:
            self.__balance -= amount
            print("Amount withdrawn successfully")

    # Display method
    def display(self):
        print(f"Name: {self.name}")
        print(f"Balance: {self.__balance}")


accounts = []


def create_account():
    name = input("Enter name: ")
    balance = float(input("Enter initial balance: "))

    acc = BankAccount(name, balance)
    accounts.append(acc)
    print("Account created successfully\n")


def deposit_money():
    name = input("Enter account holder name: ")
    amount = float(input("Enter amount: "))

    for acc in accounts:
        if acc.name == name:
            acc.deposit(amount)
            return
    print("Account not found!")


def withdraw_money():
    name = input("Enter account holder name: ")
    amount = float(input("Enter amount: "))

    for acc in accounts:
        if acc.name == name:
            acc.withdraw(amount)
            return
    print("Account not found!")


def check_balance():
    name = input("Enter account holder name: ")

    for acc in accounts:
        if acc.name == name:
            print("Balance:", acc.get_balance())
            return
    print("Account not found!")


def display_all():
    if not accounts:
        print("No accounts found\n")
        return

    for i, acc in enumerate(accounts, 1):
        print(f"\n--- Account {i} ---")
        acc.display()


# Menu
while True:
    print("\n===== Bank System (Encapsulation) =====")
    print("1. Create Account")
    print("2. Deposit")
    print("3. Withdraw")
    print("4. Check Balance")
    print("5. Show All Accounts")
    print("6. Exit")

    choice = input("Enter choice: ")

    if choice == "1":
        create_account()
    elif choice == "2":
        deposit_money()
    elif choice == "3":
        withdraw_money()
    elif choice == "4":
        check_balance()
    elif choice == "5":
        display_all()
    elif choice == "6":
        print("Exiting...")
        break
    else:
        print("Invalid choice!")
# Out:
# ===== Bank System (Encapsulation) =====
# 1. Create Account
# 2. Deposit
# 3. Withdraw
# 4. Check Balance
# 5. Show All Accounts
# 6. Exit
# Enter choice:  1
# Enter name:  patel surendra
# Enter initial balance:  50000
# Account created successfully
#
#
# ===== Bank System (Encapsulation) =====
# 1. Create Account
# 2. Deposit
# 3. Withdraw
# 4. Check Balance
# 5. Show All Accounts
# 6. Exit
# Enter choice:  2
# Enter account holder name:  patel surendra
# Enter amount:  3400
# Amount deposited successfully
#
# ===== Bank System (Encapsulation) =====
# 1. Create Account
# 2. Deposit
# 3. Withdraw
# 4. Check Balance
# 5. Show All Accounts
# 6. Exit
# Enter choice:  5
# --- Account 1 ---
# Name: patel surendra
# Balance: 53400.0
#
# ===== Bank System (Encapsulation) =====
# 1. Create Account
# 2. Deposit
# 3. Withdraw
# 4. Check Balance
# 5. Show All Accounts
# 6. Exit
# Enter choice:  1
# Enter name:  zalak patel
# Enter initial balance:  3000
# Account created successfully
#
#
# ===== Bank System (Encapsulation) =====
# 1. Create Account
# 2. Deposit
# 3. Withdraw
# 4. Check Balance
# 5. Show All Accounts
# 6. Exit
# Enter choice:  3
# Enter account holder name:  zalak patel
# Enter amount:  2500
# Account not found!
#
# ===== Bank System (Encapsulation) =====
# 1. Create Account
# 2. Deposit
# 3. Withdraw
# 4. Check Balance
# 5. Show All Accounts
# 6. Exit
